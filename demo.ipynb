# %%
from pathlib import Path
import data_transformation as transformer
import crewai_mapper as mapper
import data_ingestion as ingestion

# %% [markdown]
# ## 1. Data ingestion

# %%
INPUT_PATH = Path("./input_data/Openstaande posten crediteuren 300423 SAP.XLSX")

# %% [markdown]
# ### Ingest validation rules

# %%
# These rules are easily configurable by a technical expert
VALIDATION_RULES = ingestion.VALIDATION_RULES

# %%
df = ingestion.file_ingestion(path_dir=INPUT_PATH)

# %% [markdown]
# Outputting input data to show original data read in from XLSX.

# %%
df
# Out:
#     Symbol Posten offen/ausg.   Zuordnung   Belegnummer Belegart Belegdatum  \
# 0                         NaN  6090466822  1.200402e+09       RE 2023-04-30
# 1                         NaN  6090466823  1.200402e+09       RE 2023-04-30
# 2                 @5C\Qoffen@         NaN           NaN      NaN        NaT
# 3              Konto 30036349         NaN           NaN      NaN        NaT
# 4                         NaN  9503325616  1.200401e+09       RE 2023-04-25
# ..                        ...         ...           ...      ...        ...
# 683            Konto 30139870         NaN           NaN      NaN        NaT
# 684                       NaN  1283362112  1.100129e+09       KR 2023-04-12
# 685               @5C\Qoffen@         NaN           NaN      NaN        NaT
# 686            Konto 30140793         NaN           NaN      NaN        NaT
# 687                       NaN         NaN           NaN      NaN        NaT
#
#      Sonderhauptb.Kennz.  Symbol Nettofälligkeit  Betrag in Hauswährung  \
# 0                    NaN                     NaN               51671.15
# 1                    NaN                     NaN                3919.22
# 2                    NaN                     NaN               55590.37
# 3                    NaN                     NaN               55590.37
# 4                    NaN                     NaN                -115.65
# ..                   ...                     ...                    ...
# 683                  NaN                     NaN             -165902.22
# 684                  NaN                     NaN                 -92.56
# 685                  NaN                     NaN                 -92.56
# 686                  NaN                     NaN                 -92.56
# 687                  NaN                     NaN            -1736919.08
#
#     Hauswährung  Ausgleichsbeleg                             Text
# 0           EUR              NaN                              NaN
# 1           EUR              NaN                              NaN
# 2           EUR              NaN                              NaN
# 3           EUR              NaN                              NaN
# 4           EUR     1.600014e+09                              NaN
# ..          ...              ...                              ...
# 683         EUR              NaN                              NaN
# 684         EUR     1.600014e+09  Jumbo-1283362112 keuken/kantoor
# 685         EUR              NaN                              NaN
# 686         EUR              NaN                              NaN
# 687         EUR              NaN                              NaN
#
# [688 rows x 11 columns]

# %% [markdown]
# ## 2. Transform data

# %%
sub_df = transformer.transform_nonstandard_SAP(df=df, new_column_name="Cust. name")
csv = sub_df.head(10).to_csv(sep=',')

# %% [markdown]
# The `transformer` provides convenient functions to work on the data, such as adding new customer names.

# %%
sub_df
# Out:
#       Zuordnung   Belegnummer Belegart Belegdatum  Sonderhauptb.Kennz.  \
# 0    6090466822  1.200402e+09       RE 2023-04-30                  NaN
# 1    6090466823  1.200402e+09       RE 2023-04-30                  NaN
# 4    9503325616  1.200401e+09       RE 2023-04-25                  NaN
# 5    9503328298  1.200401e+09       RE 2023-04-26                  NaN
# 6    9503328299  1.200401e+09       RE 2023-04-26                  NaN
# ..          ...           ...      ...        ...                  ...
# 678  0090861991  1.200402e+09       RE 2023-04-28                  NaN
# 679  0090861992  1.200402e+09       RE 2023-04-28                  NaN
# 680  0090861993  1.200402e+09       RE 2023-04-28                  NaN
# 681  0090861994  1.200402e+09       RE 2023-04-30                  NaN
# 684  1283362112  1.100129e+09       KR 2023-04-12                  NaN
#
#      Symbol Nettofälligkeit  Betrag in Hauswährung Hauswährung  \
# 0                       NaN               51671.15         EUR
# 1                       NaN                3919.22         EUR
# 4                       NaN                -115.65         EUR
# 5                       NaN                -216.41         EUR
# 6                       NaN                -710.99         EUR
# ..                      ...                    ...         ...
# 678                     NaN               -1321.25         EUR
# 679                     NaN                -104.66         EUR
# 680                     NaN                -265.97         EUR
# 681                     NaN               -3456.50         EUR
# 684                     NaN                 -92.56         EUR
#
#      Ausgleichsbeleg                             Text  \
# 0                NaN                              NaN
# 1                NaN                              NaN
# 4       1.600014e+09                              NaN
# 5       1.600014e+09                              NaN
# 6       1.600014e+09                              NaN
# ..               ...                              ...
# 678     1.600014e+09                              NaN
# 679     1.600014e+09                              NaN
# 680     1.600014e+09                              NaN
# 681     1.600014e+09                              NaN
# 684     1.600014e+09  Jumbo-1283362112 keuken/kantoor
#
#                         Cust. name
# 0    (@5C\Qoffen@, Konto 30036349)
# 1    (@5C\Qoffen@, Konto 30036349)
# 4    (@5C\Qoffen@, Konto 30039682)
# 5    (@5C\Qoffen@, Konto 30039682)
# 6    (@5C\Qoffen@, Konto 30039682)
# ..                             ...
# 678  (@5C\Qoffen@, Konto 30139870)
# 679  (@5C\Qoffen@, Konto 30139870)
# 680  (@5C\Qoffen@, Konto 30139870)
# 681  (@5C\Qoffen@, Konto 30139870)
# 684  (@5C\Qoffen@, Konto 30140793)
#
# [655 rows x 11 columns]

# %% [markdown]
# ### Retrieve Validation

# %%
DESTINATION_COLUMNS = VALIDATION_RULES["parametres"]["names"]
SOURCE_COLUMNS = sub_df.columns.to_list()
TO_DISCARD = VALIDATION_RULES["parametres"]["to_discard"]

# %% [markdown]
# ## 3. CrewAI mapping suggestion

# %%
response = mapper.get_mapping(expected=DESTINATION_COLUMNS, input=csv)
# Out:
# > Entering new CrewAgentExecutor chain...
# I need to work on the dataset to find the potential matches
#
# Final Answer:
# Datum --> Belegdatum
# Bedrag_EUR --> Betrag in Hauswährung
# Debiteurnaam --> Cust. name
# Factuurnummer --> Belegnummer
#
# Note: The potential matches are the columns that have the same content as the input columns. For example, Datum in the input has the same content as Belegdatum in the dataset, so it is a potential match.
#
# The content of the potential matches are:
# - Cust. name: ("('@5C\\Qoffen@', 'Konto 30036349')", "('@5C\\Qoffen@', 'Konto 30039682')", "('@5C\\Qoffen@', 'Konto 30090238')")
# - Belegdatum: ('2023-04-30', '2023-04-30', '2023-04-25', '2023-04-26', '2023-04-26', '2023-04-26', '2023-03-27', '2023-04-04')
# - Betrag in Hauswährung: ('51671.15', '3919.22', '-115.65', '-216.41', '-710.99', '-227.38', '-3019.29', '-8079.25')
# - Belegnummer: ('6090466822', '6090466823', '9503325616', '9503328298', '9503328299', '9503331521', '0096911384', '0096913057')
#
# Therefore, these are the potential matches for the input columns ['Debiteurnaam', 'Factuurnummer', 'Datum', 'Bedrag_EUR'] in the dataset columns Zuordnung, Belegnummer, Belegart, Belegdatum, Sonderhauptb.Kennz., Symbol Nettofälligkeit, Betrag in Hauswährung, Hauswährung, Ausgleichsbeleg, Text, Cust. name:
# - Datum --> Belegdatum
# - Bedrag_EUR --> Betrag in Hauswährung
# - Debiteurnaam --> Cust. name
# - Factuurnummer --> Belegnummer
#
# The Cust. name column in the dataset has the same content as the Debiteurnaam column in the input, so it is a potential match.
#
# The Belegdatum column in the dataset has the same content as the Datum column in the input, so it is a potential match.
#
# The Betrag in Hauswährung column in the dataset has the same content as the Bedrag_EUR column in the input, so it is a potential match.
#
# The Belegnummer column in the dataset has the same content as the Factuurnummer column in the input, so it is a potential match.
#
# The other columns in the dataset are not potential matches because they do not have the same content as the input columns.
#
# The content of the potential matches are:
# - Cust. name: ("('@5C\\Qoffen@', 'Konto 30036349')", "('@5C\\Qoffen@', 'Konto 30039682')", "('@5C\\Qoffen@', 'Konto 30090238')")
# - Belegdatum: ('2023-04-30', '2023-04-30', '2023-04-25', '2023-04-26', '2023-04-26', '2023-04-26', '2023-03-27', '2023-04-04')
# - Betrag in Hauswährung: ('51671.15', '3919.22', '-115.65', '-216.41', '-710.99', '-227.38', '-3019.29', '-8079.25')
# - Belegnummer: ('6090466822', '6090466823', '9503325616', '9503328298', '9503328299', '9503331521', '0096911384', '0096913057')<|im_end|>
#
# > Finished chain.

# %% [markdown]
# ## 4. Map data according to suggestion

# %%
source_columns = transformer.extract_substrings(response, SOURCE_COLUMNS)
destination_columns = transformer.extract_substrings(response, DESTINATION_COLUMNS)
mapping = transformer.create_mapping(source_columns=source_columns, 
                                     destination_columns=destination_columns)

# %%
mapping
# Out:
# {'Belegdatum': 'Datum',
#  'Betrag in Hauswährung': 'Bedrag_EUR',
#  'Cust. name': 'Debiteurnaam',
#  'Belegnummer': 'Factuurnummer'}

# %%
mapped_df = transformer.mapper(mapping=mapping, to_discard=TO_DISCARD, df=sub_df)

# %% [markdown]
# After processing the suggestions fron the AI with the convenient built ins from the `transformer` we have a dataframe to use for mapping to a final output now.

# %%
mapped_df
# Out:
#      Factuurnummer      Datum  Bedrag_EUR                   Debiteurnaam
# 0     1.200402e+09 2023-04-30    51671.15  (@5C\Qoffen@, Konto 30036349)
# 1     1.200402e+09 2023-04-30     3919.22  (@5C\Qoffen@, Konto 30036349)
# 4     1.200401e+09 2023-04-25     -115.65  (@5C\Qoffen@, Konto 30039682)
# 5     1.200401e+09 2023-04-26     -216.41  (@5C\Qoffen@, Konto 30039682)
# 6     1.200401e+09 2023-04-26     -710.99  (@5C\Qoffen@, Konto 30039682)
# ..             ...        ...         ...                            ...
# 678   1.200402e+09 2023-04-28    -1321.25  (@5C\Qoffen@, Konto 30139870)
# 679   1.200402e+09 2023-04-28     -104.66  (@5C\Qoffen@, Konto 30139870)
# 680   1.200402e+09 2023-04-28     -265.97  (@5C\Qoffen@, Konto 30139870)
# 681   1.200402e+09 2023-04-30    -3456.50  (@5C\Qoffen@, Konto 30139870)
# 684   1.100129e+09 2023-04-12      -92.56  (@5C\Qoffen@, Konto 30140793)
#
# [655 rows x 4 columns]
